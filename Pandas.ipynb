# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(0,20).reshape(5,4),columns = ['Col1','Col2','Col3','Col4'],index = ['Row1','Row2',"Row3","Row4","Row5"])
# print(df.head(3))
# df.to_csv('Test.csv')
print(df)
print(df.iloc[2,3])
print(df.loc['Row3','Col1'])
print(df.loc['Row1'])
print(df.iloc[:,3])
a = df.iloc[:,2].values # converting a dataframe extracted from iloc to an array
print(a)
print(df['Col1'].value_counts())
print(df.isnull())
print(df.isnull().sum())
# print(df['Row1'].unique())
print(df['Col1'].unique())
# Out:
#       Col1  Col2  Col3  Col4
# Row1     0     1     2     3
# Row2     4     5     6     7
# Row3     8     9    10    11
# Row4    12    13    14    15
# Row5    16    17    18    19
# 11
# 8
# Col1    0
# Col2    1
# Col3    2
# Col4    3
# Name: Row1, dtype: int32
# Row1     3
# Row2     7
# Row3    11
# Row4    15
# Row5    19
# Name: Col4, dtype: int32
# [ 2  6 10 14 18]
# Col1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: count, dtype: int64
#        Col1   Col2   Col3   Col4
# Row1  False  False  False  False
# Row2  False  False  False  False
# Row3  False  False  False  False
# Row4  False  False  False  False
# Row5  False  False  False  False
# Col1    0
# Col2    0
# Col3    0
# Col4    0
# dtype: int64
# [ 0  4  8 12 16]

# %%
data = pd.read_csv('train.csv')
print(data.head(1))
print("Info")
print(data.info())
print(df.describe())
print(data[data['Age']<30])
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# ...
